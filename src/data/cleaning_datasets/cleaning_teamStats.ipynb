# %% [markdown]
# ### Import Dependencies

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Read CSV file.

# %%
df = pd.read_csv("../scraped_csv/team_stats/20162017_team_stats.csv")
df
# Out:
#     team_id  season  stat.gamesPlayed stat.wins stat.losses stat.ot stat.pts  \
# 0         1    2016              82.0        28          40      14       70
# 1         1    2016               NaN      29th        27th     3rd     27th
# 2         2    2016              82.0        41          29      12       94
# 3         2    2016               NaN      16th        14th     6th     15th
# 4         3    2016              82.0        48          28       6      102
# 5         3    2016               NaN       6th        10th    28th      9th
# 6         4    2016              82.0        39          33      10       88
# 7         4    2016               NaN      20th        20th    14th     19th
# 8         5    2016              82.0        50          21      11      111
# 9         5    2016               NaN       2nd         2nd     9th      2nd
# 10        6    2016              82.0        44          31       7       95
# ...

# %%
df_even = df.iloc[::2]
df_odd = df.iloc[1::2]

# %%
df_even.columns
# Out:
# Index(['team_id', 'season', 'stat.gamesPlayed', 'stat.wins', 'stat.losses',
#        'stat.ot', 'stat.pts', 'stat.ptPctg', 'stat.goalsPerGame',
#        'stat.goalsAgainstPerGame', 'stat.evGGARatio',
#        'stat.powerPlayPercentage', 'stat.powerPlayGoals',
#        'stat.powerPlayGoalsAgainst', 'stat.powerPlayOpportunities',
#        'stat.penaltyKillPercentage', 'stat.shotsPerGame', 'stat.shotsAllowed',
#        'stat.winScoreFirst', 'stat.winOppScoreFirst', 'stat.winLeadFirstPer',
#        'stat.winLeadSecondPer', 'stat.winOutshootOpp', 'stat.winOutshotByOpp',
#        'stat.faceOffsTaken', 'stat.faceOffsWon', 'stat.faceOffsLost',
#        'stat.faceOffWinPercentage', 'stat.shootingPctg', 'stat.savePctg',
#        'team.id', 'team.name', 'team.link', 'stat.penaltyKillOpportunities',
#        'stat.savePctRank', 'stat.shootingPctRank'],
#       dtype='object')

# %%
df_odd.columns
# Out:
# Index(['team_id', 'season', 'stat.gamesPlayed', 'stat.wins', 'stat.losses',
#        'stat.ot', 'stat.pts', 'stat.ptPctg', 'stat.goalsPerGame',
#        'stat.goalsAgainstPerGame', 'stat.evGGARatio',
#        'stat.powerPlayPercentage', 'stat.powerPlayGoals',
#        'stat.powerPlayGoalsAgainst', 'stat.powerPlayOpportunities',
#        'stat.penaltyKillPercentage', 'stat.shotsPerGame', 'stat.shotsAllowed',
#        'stat.winScoreFirst', 'stat.winOppScoreFirst', 'stat.winLeadFirstPer',
#        'stat.winLeadSecondPer', 'stat.winOutshootOpp', 'stat.winOutshotByOpp',
#        'stat.faceOffsTaken', 'stat.faceOffsWon', 'stat.faceOffsLost',
#        'stat.faceOffWinPercentage', 'stat.shootingPctg', 'stat.savePctg',
#        'team.id', 'team.name', 'team.link', 'stat.penaltyKillOpportunities',
#        'stat.savePctRank', 'stat.shootingPctRank'],
#       dtype='object')

# %% [markdown]
# ### Let's transpose to see all the columns and values easier.

# %%
df_even = df_even.transpose()
df_even
# Out:
#                                               0                   2   \
# team_id                                        1                   2
# season                                      2016                2016
# stat.gamesPlayed                            82.0                82.0
# stat.wins                                     28                  41
# stat.losses                                   40                  29
# stat.ot                                       14                  12
# stat.pts                                      70                  94
# stat.ptPctg                                 42.7                57.3
# stat.goalsPerGame                          2.195               2.915
# stat.goalsAgainstPerGame                   2.939               2.902
# stat.evGGARatio                           0.7651              1.0471
# stat.powerPlayPercentage                    17.5                15.0
# stat.powerPlayGoals                         44.0                35.0
# ...

# %% [markdown]
# ### Looking at dataset, there are a couple of things we need to do:
# - Remove the .0 at the end of the jersey numbers
# - Delete the columns not fitting in the database schema
# - Rename column names to align with database schema
# - Add the `stats.savePctRank` and the `stat.shootingPctRank` in the rankings for the columns `stat.shootingPctg` and `stat.savePctg`
#
# So let's go ahead and do these tasks.

# %% [markdown]
# #### However, also note that we need to do this for every single team_stats dataset and then combine all those cleaned datasets into one dataset to fit the database schema. Thus, we will make a single function to accomplish all these tasks.

# %%
# making function

def cleaning_dataset(data): 
    df = pd.read_csv(data)
    
    df_even = df.iloc[::2]
    df_odd = df.iloc[1::2]

    def clean_even_data(data):
        # converting all NaN values to 0
        # then removing .0 at end of gamesPlayed stat by changing type from float to int
        df = data.copy(deep=True)
        df = df.replace(np.NaN, 0)
        df = df.astype({'stat.gamesPlayed':np.int64})

        # # Adding the `stats.savePctRank` and the `stat.shootingPctRank` in the rankings 
        # # for the columns `stat.shootingPctg` and `stat.savePctg`
        # # df.loc[1,'stat.shootingPctg'] = int(df['stat.shootingPctRank'][1].replace('th', ''))
        # df.loc[1,'stat.shootingPctg'] = df['stat.shootingPctRank'][1]
        # # df.loc[1,'stat.savePctg'] = int(df['stat.savePctRank'][1].replace('th', ''))
        # df.loc[1,'stat.savePctg'] = df['stat.savePctRank'][1]

        # dropping useless columns
        dropped_columns = [
            'team.id', 
            'team.name', 
            'team.link', 
            'stat.penaltyKillOpportunities',
            'stat.savePctRank', 
            'stat.shootingPctRank'
        ]
        df = df.drop(columns=dropped_columns)

        # renaming columns to more meaningful name
        renamed_columns = {
            'stat.gamesPlayed':'games_played', 
            'stat.wins': 'games_won', 
            'stat.losses': 'games_lost', 
            'stat.ot': 'games_lost_ot', 
            'stat.pts': 'points',
            'stat.ptPctg': 'points_pct', 
            'stat.goalsPerGame': 'goals_per_game', 
            'stat.goalsAgainstPerGame': 'goals_against_per_game',
            'stat.evGGARatio': 'ev_gga_ratio',
            'stat.powerPlayPercentage': 'powerplay_pct', 
            'stat.powerPlayGoals' : 'powerplay_goals',
            'stat.powerPlayGoalsAgainst': 'powerplay_goals_against', 
            'stat.powerPlayOpportunities': 'powerplay_opportunities',
            'stat.penaltyKillPercentage': 'penaltykill_pct', 
            'stat.penaltyKillOpportunities': 'penaltykill_opportunities',
            'stat.shotsPerGame': 'shots_per_game', 
            'stat.shotsAllowed': 'shots_allowed',
            'stat.winScoreFirst': 'win_when_score_first', 
            'stat.winOppScoreFirst': 'win_when_opp_score_first', 
            'stat.winLeadFirstPer': 'win_when_leading_first_per',
            'stat.winLeadSecondPer': 'win_when_leading_second_per', 
            'stat.winOutshootOpp': 'win_when_outshooting_opp', 
            'stat.winOutshotByOpp': 'win_when_opp_outshooting',
            'stat.faceOffsTaken': 'faceoffs_taken', 
            'stat.faceOffsWon': 'faceoffs_won', 
            'stat.faceOffsLost': 'faceoffs_lost',
            'stat.faceOffWinPercentage': 'faceoff_win_pct', 
            'stat.shootingPctg': 'shooting_pct', 
            'stat.savePctg': 'save_pct',
        }
        df = df.rename(columns=renamed_columns)
        return df
    
    def clean_odd_data(data):
        # converting all NaN values to 0
        # then removing .0 at end of gamesPlayed stat by changing type from float to int
        df = data.copy(deep=True)
        df = df.replace(np.NaN, 0)
        df = df.astype({'stat.gamesPlayed':np.int64})

        # # Adding the `stats.savePctRank` and the `stat.shootingPctRank` in the rankings 
        # # for the columns `stat.shootingPctg` and `stat.savePctg`
        # # df.loc[1,'stat.shootingPctg'] = int(df['stat.shootingPctRank'][1].replace('th', ''))
        # df.loc[1,'stat.shootingPctg'] = df['stat.shootingPctRank'][1]
        # # df.loc[1,'stat.savePctg'] = int(df['stat.savePctRank'][1].replace('th', ''))
        # df.loc[1,'stat.savePctg'] = df['stat.savePctRank'][1]

        # dropping useless columns
        dropped_columns = [
            'stat.gamesPlayed',
            'team.id', 
            'team.name', 
            'team.link', 
            'stat.penaltyKillOpportunities',
            'stat.shootingPctg',
            'stat.savePctg'
        ]
        df = df.drop(columns=dropped_columns)

        # renaming columns to more meaningful name
        renamed_columns = {
            'stat.wins': 'games_won', 
            'stat.losses': 'games_lost', 
            'stat.ot': 'games_lost_ot', 
            'stat.pts': 'points',
            'stat.ptPctg': 'points_pct', 
            'stat.goalsPerGame': 'goals_per_game', 
            'stat.goalsAgainstPerGame': 'goals_against_per_game',
            'stat.evGGARatio': 'ev_gga_ratio',
            'stat.powerPlayPercentage': 'powerplay_pct', 
            'stat.powerPlayGoals' : 'powerplay_goals',
            'stat.powerPlayGoalsAgainst': 'powerplay_goals_against', 
            'stat.powerPlayOpportunities': 'powerplay_opportunities',
            'stat.penaltyKillPercentage': 'penaltykill_pct', 
            'stat.penaltyKillOpportunities': 'penaltykill_opportunities',
            'stat.shotsPerGame': 'shots_per_game', 
            'stat.shotsAllowed': 'shots_allowed',
            'stat.winScoreFirst': 'win_when_score_first', 
            'stat.winOppScoreFirst': 'win_when_opp_score_first', 
            'stat.winLeadFirstPer': 'win_when_leading_first_per',
            'stat.winLeadSecondPer': 'win_when_leading_second_per', 
            'stat.winOutshootOpp': 'win_when_outshooting_opp', 
            'stat.winOutshotByOpp': 'win_when_opp_outshooting',
            'stat.faceOffsTaken': 'faceoffs_taken', 
            'stat.faceOffsWon': 'faceoffs_won', 
            'stat.faceOffsLost': 'faceoffs_lost',
            'stat.faceOffWinPercentage': 'faceoff_win_pct', 
            'stat.savePctRank': 'save_pct', 
            'stat.shootingPctRank': 'shooting_pct'
        }
        df = df.rename(columns=renamed_columns)

        return df

    stats = clean_even_data(df_even)
    ranks = clean_odd_data(df_odd)

    return stats, ranks

# %%
stats = cleaning_dataset("../scraped_csv/team_stats/20162017_team_stats.csv")[0]
stats.isna().sum()
# Out:
# team_id                        0
# season                         0
# games_played                   0
# games_won                      0
# games_lost                     0
# games_lost_ot                  0
# points                         0
# points_pct                     0
# goals_per_game                 0
# goals_against_per_game         0
# ev_gga_ratio                   0
# powerplay_pct                  0
# powerplay_goals                0
# powerplay_goals_against        0
# powerplay_opportunities        0
# penaltykill_pct                0
# shots_per_game                 0
# shots_allowed                  0
# win_when_score_first           0
# win_when_opp_score_first       0
# win_when_leading_first_per     0
# win_when_leading_second_per    0
# win_when_outshooting_opp       0
# win_when_opp_outshooting       0
# faceoffs_taken                 0
# faceoffs_won                   0
# faceoffs_lost                  0
# faceoff_win_pct                0
# ...

# %%
ranks = cleaning_dataset("../scraped_csv/team_stats/20162017_team_stats.csv")[1]
ranks.isna().sum()
# Out:
# team_id                        0
# season                         0
# games_won                      0
# games_lost                     0
# games_lost_ot                  0
# points                         0
# points_pct                     0
# goals_per_game                 0
# goals_against_per_game         0
# ev_gga_ratio                   0
# powerplay_pct                  0
# powerplay-goals                0
# powerplay_goals_against        0
# powerplay_opportunities        0
# penaltykill_pct                0
# shots_per_game                 0
# shots_allowed                  0
# win_when_score_first           0
# win_when_opp_score_first       0
# win_when_leading_first_per     0
# win_when_leading_second_per    0
# win_when_outshooting_opp       0
# win_when_opp_outshooting       0
# faceoffs_taken                 0
# faceoffs_won                   0
# faceoffs_lost                  0
# faceoff_win_pct                0
# save_pct                       0
# ...

# %% [markdown]
# ### Now, we can make a loop to go through all of the stats datasets, apply the function to all of them, and then concatenate all the results into one csv file.

# %% [markdown]
# #### This will be done by looping through all the datasets such that the function:
# - Applies modifications to each dataset
# - Merges all the datasets together with their year number to fit database schema.

# %%
# get list of all team stats datasets
stats_datasets_seasons = list(map(lambda x: x.split("_")[0], os.listdir("../scraped_csv/team_stats/")))
stats_datasets_seasons
# Out:
# ['20162017',
#  '20172018',
#  '20182019',
#  '20192020',
#  '20202021',
#  '20212022',
#  '20222023',
#  '20232024']

# %%
# do this for every roster dataset
all_stats = pd.DataFrame()
all_ranks = pd.DataFrame()
for season in stats_datasets_seasons:
    stats, ranks = cleaning_dataset(f"../scraped_csv/team_stats/{season}_team_stats.csv") 
    all_stats = pd.concat([all_stats, stats], ignore_index=True) 
    all_ranks = pd.concat([all_ranks, ranks], ignore_index=True)

# %%
x = all_stats.columns
y = all_ranks.columns

for column in x:
    if column not in y:
        print(column)
# Out:
# games_played

# %% [markdown]
# ### Lets finally export the cleansed dataframe into a csv file

# %%
title = '../cleaned_csv/4_teamAllStatsCleaned.csv'
all_stats.to_csv(title, index=True)

# %%
title = '../cleaned_csv/5_teamAllRanksCleaned.csv'
all_ranks.to_csv(title, index=True)

# %%
# how to get csv back into dataframe

a = pd.read_csv('../cleaned_csv/teamAllStatsDetailsCleaned.csv')
teamStats = a.to_dict(orient='list')
for key in teamRosters.keys():
    for i in range(len(teamRosters[key])):
        temp = ast.literal_eval(teamRosters[key][i])
        teamRosters[key][i] = temp
c = pd.DataFrame.from_dict(b, orient='columns')
rows = {
    0 : 'stats',
    1 : 'ranks'
}
c = c.rename(index=rows)
c
