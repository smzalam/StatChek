# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read CSV file.

# %%
df = pd.read_csv("../scraped_csv/team_details/teamFranchiseDetails.csv")
df
# Out:
#    id                 name              link abbreviation     teamName  \
# 0  10  Toronto Maple Leafs  /api/v1/teams/10          TOR  Maple Leafs
#
#   locationName  firstYearOfPlay shortName             officialSiteUrl  \
# 0      Toronto             1917   Toronto  http://www.mapleleafs.com/
#
#    franchiseId  ...  division.name division.nameShort         division.link  \
# 0            5  ...       Atlantic                ATL  /api/v1/divisions/17
#
#   division.abbreviation conference.id  conference.name        conference.link  \
# 0                     A             6          Eastern  /api/v1/conferences/6
#
#   franchise.franchiseId franchise.teamName        franchise.link
# 0                     5        Maple Leafs  /api/v1/franchises/5
#
# [1 rows x 26 columns]

# %% [markdown]
# ### Hard to see all columns, so lets see the transposed dataframe instead.

# %%
df = df.transpose()
df
# Out:
#                                                                        0
# id                                                                    10
# name                                                 Toronto Maple Leafs
# link                                                    /api/v1/teams/10
# abbreviation                                                         TOR
# teamName                                                     Maple Leafs
# locationName                                                     Toronto
# firstYearOfPlay                                                     1917
# shortName                                                        Toronto
# officialSiteUrl                               http://www.mapleleafs.com/
# franchiseId                                                            5
# active                                                              True
# venue.name                                              Scotiabank Arena
# venue.link                                           /api/v1/venues/null
# venue.city                                                       Toronto
# venue.timeZone         {'id': 'America/Toronto', 'offset': -4, 'tz': ...
# division.id                                                           17
# division.name                                                   Atlantic
# division.nameShort                                                   ATL
# division.link                                       /api/v1/divisions/17
# division.abbreviation                                                  A
# conference.id                                                          6
# conference.name                                                  Eastern
# conference.link                                    /api/v1/conferences/6
# franchise.franchiseId                                                  5
# franchise.teamName                                           Maple Leafs
# franchise.link                                      /api/v1/franchises/5

# %% [markdown]
# ### Looking at database schema, we only need some of these columns, so I will now remove columns that are not needed.

# %%
dropped_columns = [
    'link', 
    'teamName', 
    'shortName', 
    'franchiseId', 
    'active', 
    'venue.link', 
    'venue.city', 
    'venue.timeZone', 
    'division.id', 
    'division.abbreviation', 
    'division.link', 
    'conference.id', 
    'conference.link', 
    'franchise.franchiseId', 
    'franchise.teamName', 
    'franchise.link'
]
df = df.drop(dropped_columns)
df
# Out:
#                                              0
# id                                          10
# name                       Toronto Maple Leafs
# abbreviation                               TOR
# locationName                           Toronto
# firstYearOfPlay                           1917
# officialSiteUrl     http://www.mapleleafs.com/
# venue.name                    Scotiabank Arena
# division.name                         Atlantic
# division.nameShort                         ATL
# conference.name                        Eastern

# %% [markdown]
# ### It will be easier to see full list and other blocks of code horizontally so we once again transpose the dataframe.

# %%
df = df.transpose()
df
# Out:
#    id                 name abbreviation locationName firstYearOfPlay  \
# 0  10  Toronto Maple Leafs          TOR      Toronto            1917
#
#               officialSiteUrl        venue.name division.name  \
# 0  http://www.mapleleafs.com/  Scotiabank Arena      Atlantic
#
#   division.nameShort conference.name
# 0                ATL         Eastern

# %% [markdown]
# ### Let's rename these columns to something more meaningful.

# %%
renamed_columns = {
    'id': 'apiID', 
    'locationName': 'city', 
    'officialSiteUrl': 'websiteURL', 
    'venue.name': 'venue', 
    'division.name': 'divison', 
    'division.nameShort': 'divisionAbbr', 
    'conference.name':'conference', 
}
df = df.rename(columns=renamed_columns)
df
# Out:
#   apiID                 name abbreviation     city firstYearOfPlay  \
# 0    10  Toronto Maple Leafs          TOR  Toronto            1917
#
#                    websiteURL             venue   divison divisionAbbr  \
# 0  http://www.mapleleafs.com/  Scotiabank Arena  Atlantic          ATL
#
#   conference
# 0    Eastern

# %% [markdown]
# ### Let's check if the csv shows up as we want to in the format it will be inserted into the database in

# %%
payload = df.to_dict(orient='records')
payload
# Out:
# [{'apiID': 10,
#   'name': 'Toronto Maple Leafs',
#   'abbreviation': 'TOR',
#   'city': 'Toronto',
#   'firstYearOfPlay': 1917,
#   'websiteURL': 'http://www.mapleleafs.com/',
#   'venue': 'Scotiabank Arena',
#   'divison': 'Atlantic',
#   'divisionAbbr': 'ATL',
#   'conference': 'Eastern'}]

# %% [markdown]
# ### Lets finally export the cleansed dataframe into a csv file

# %%
title = '../cleaned_csv/teamFranchiseDetailsCleaned.csv'
df.to_csv(title, index=False)

# %%
# how to get csv back into dataframe

a = pd.read_csv('../cleaned_csv/teamFranchiseDetailsCleaned.csv')
b = a.to_dict(orient='list')
c = pd.DataFrame.from_dict(b, orient='columns')
c
# Out:
#    apiID                 name abbreviation     city  firstYearOfPlay  \
# 0     10  Toronto Maple Leafs          TOR  Toronto             1917
#
#                    websiteURL             venue   divison divisionAbbr  \
# 0  http://www.mapleleafs.com/  Scotiabank Arena  Atlantic          ATL
#
#   conference
# 0    Eastern
